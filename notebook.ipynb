# %%
from tfpnp.pnp.denoiser import UNetDenoiser2D

denosier = UNetDenoiser2D()
# Out:
# <bound method Module.parameters of UNetDenoiser2D(
#   (net): UNet(
#     (inc): inconv(
#       (conv): ConvBlock(
#         (conv-0): ConvLayer(
#           (conv2d): Conv2d(2, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (act): LeakyReLU(negative_slope=0.2)
#         )
#         (conv-1): ConvLayer(
#           (conv2d): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (act): LeakyReLU(negative_slope=0.2)
#         )
#         (conv-2): ConvLayer(
#           (conv2d): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (act): LeakyReLU(negative_slope=0.2)
#         )
#       )
#     )
#     (down1): down(
#       (mpconv): Sequential(
#         (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (1): ConvBlock(
#           (conv-0): ConvLayer(
#             (conv2d): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ...
